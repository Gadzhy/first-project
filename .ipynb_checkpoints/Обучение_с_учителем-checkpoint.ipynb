# %% [markdown]
# ## Исследование покупательской активности интернет-магазина «В один клик»

# %% [markdown]
# В данном проекте я построю модель предсказания вероятности снижения покупательской активности клиента, выделю сегменты покупателей и разработаю для них персональные предложения.
#
#     Описание данных:
#
# market_file:
#
# - `id` - номер покупателя в корпоративной базе данных
# - `Покупательская активность`- рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень»
# - `Тип сервиса` - уровень сервиса, например «премиум» и «стандарт»
# - `Разрешить сообщать` - информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель
# - `Маркет_актив_6_мес` - среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента
# - `Маркет_актив_тек_мес`- количество маркетинговых коммуникаций в текущем месяце
# - `Длительность` - значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте
# - `Акционные_покупки` - среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев
# - `Популярная_категория` - самая популярная категория товаров у покупателя за последние 6 месяцев.
# - `Средний_просмотр_категорий_за_визит` - показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца
# - `Неоплаченные_продукты_штук_квартал` - общее число неоплаченных товаров в корзине за последние 3 месяца
# - `Ошибка_сервиса` - число сбоев, которые коснулись покупателя во время посещения сайта
# - `Страниц_за_визит` - среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца
#
# market_money:
#
# - `id` - номер покупателя в корпоративной базе данных
# - `Период`- название периода, во время которого зафиксирована выручка. Например,'текущий_месяц' или 'предыдущий_месяц'.
# - `Выручка` - сумма выручки за период.
#
# market_time:
#
# - `id` - номер покупателя в корпоративной базе данных
# - `Период`- название периода, во время которого зафиксировано общее время
# - `минут` - значение времени, проведённого на сайте, в минутах
#
# money:
#
# - `id` - номер покупателя в корпоративной базе данных
# - `Прибыль`- значение прибыли

# %% [markdown]
# ## Загрузка пакетов:

# %%
# !pip install phik -q

# %%
pip install shap -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import phik

from scipy import stats    

from sklearn.model_selection import (train_test_split, 
                                     RandomizedSearchCV)
from sklearn.metrics import (r2_score, 
                             mean_squared_error,
                             mean_absolute_error,
                             recall_score,
                             precision_score,
                             accuracy_score,
                             f1_score, 
                             make_scorer,
                             roc_auc_score
                            )
from sklearn.preprocessing import (StandardScaler, 
                                   OneHotEncoder, 
                                   OrdinalEncoder, 
                                   MinMaxScaler, 
                                   RobustScaler
                                  )
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
import shap
import sklearn
from collections import defaultdict

# %%
RANDOM_STATE = 1202

# %% [markdown]
# ## Загрузка данных

# %%
try:
    market_file = pd.read_csv('/Users/gadzhi/Desktop/Python SQL/market_file.csv', sep=',', decimal='.')
except:
    market_file = pd.read_csv('/datasets/market_file.csv', sep=',', decimal='.')
try:
    market_money = pd.read_csv('/Users/gadzhi/Desktop/Python SQL/market_money.csv', sep=',', decimal='.')
except:
    market_money = pd.read_csv('/datasets/market_money.csv', sep=',', decimal='.')
try:
    market_time = pd.read_csv('/Users/gadzhi/Desktop/Python SQL/market_time.csv', sep=',', decimal='.')
except:
    market_time = pd.read_csv('/datasets/market_time.csv', sep=',', decimal='.')
try:
    money = pd.read_csv('/Users/gadzhi/Desktop/Python SQL/money.csv', sep=';', decimal=',')
except:
    money = pd.read_csv('/datasets/money.csv', sep=';', decimal=',')

# %%
data = [market_file, market_money, market_time, money]

# %%
for i in data:
    display(i.head())
    display(i.info())
# Out:
#        id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0  215348                 Снизилась     премиум                 да
# 1  215349                 Снизилась     премиум                 да
# 2  215350                 Снизилась   стандартт                нет
# 3  215351                 Снизилась   стандартт                 да
# 4  215352                 Снизилась   стандартт                нет
#
#    Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  Акционные_покупки  \
# 0                 3.4                     5           121               0.00
# 1                 4.4                     4           819               0.75
# 2                 4.9                     3           539               0.14
# 3                 3.2                     5           896               0.99
# 4                 5.1                     3          1064               0.94
#
#   Популярная_категория  Средний_просмотр_категорий_за_визит  \
# 0     Товары для детей                                    6
# 1     Товары для детей                                    4
# 2    Домашний текстиль                                    5
# 3     Товары для детей                                    5
# 4     Товары для детей                                    3
#
#    Неоплаченные_продукты_штук_квартал  Ошибка_сервиса  Страниц_за_визит
# 0                                   2               1                 5
# 1                                   4               2                 5
# 2                                   2               1                 5
# 3                                   0               6                 4
# 4                                   2               3                 2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  11  Ошибка_сервиса                       1300 non-null   int64
#  12  Страниц_за_визит                     1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 132.2+ KB
# None
#        id               Период  Выручка
# 0  215348  препредыдущий_месяц      0.0
# 1  215348        текущий_месяц   3293.1
# 2  215348     предыдущий_месяц      0.0
# 3  215349  препредыдущий_месяц   4472.0
# 4  215349        текущий_месяц   4971.6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# None
#        id            Период  минут
# 0  215348     текущий_месяц     14
# 1  215348  предыдцщий_месяц     13
# 2  215349     текущий_месяц     10
# 3  215349  предыдцщий_месяц     12
# 4  215350     текущий_месяц     13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None
#        id  Прибыль
# 0  215348     0.98
# 1  215349     4.16
# 2  215350     3.13
# 3  215351     4.87
# 4  215352     4.21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB
# None

# %% [markdown]
# На первый взгляд данные соответствуют описанию. Изучу их более подробно.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Предобработка market_file

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  11  Ошибка_сервиса                       1300 non-null   int64
#  12  Страниц_за_визит                     1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 132.2+ KB

# %%
market_file = market_file.apply(lambda col: col.str.lower() if col.dtype == 'object' else col)

# %%
market_file
# Out:
#           id Покупательская активность Тип сервиса Разрешить сообщать  \
# 0     215348                 снизилась     премиум                 да
# 1     215349                 снизилась     премиум                 да
# 2     215350                 снизилась   стандартт                нет
# 3     215351                 снизилась   стандартт                 да
# 4     215352                 снизилась   стандартт                нет
# ...      ...                       ...         ...                ...
# 1295  216643           прежний уровень    стандарт                 да
# 1296  216644           прежний уровень    стандарт                нет
# 1297  216645           прежний уровень    стандарт                 да
# 1298  216646           прежний уровень    стандарт                 да
# 1299  216647           прежний уровень     премиум                 да
#
#       Маркет_актив_6_мес  Маркет_актив_тек_мес  Длительность  \
# 0                    3.4                     5           121
# 1                    4.4                     4           819
# 2                    4.9                     3           539
# 3                    3.2                     5           896
# 4                    5.1                     3          1064
# ...                  ...                   ...           ...
# 1295                 6.6                     3           318
# 1296                 5.1                     4           454
# 1297                 4.1                     3           586
# 1298                 6.3                     5           645
# 1299                 4.0                     5           906
#
#       Акционные_покупки            Популярная_категория  \
# 0                  0.00                товары для детей
# 1                  0.75                товары для детей
# 2                  0.14               домашний текстиль
# 3                  0.99                товары для детей
# 4                  0.94                товары для детей
# ...                 ...                             ...
# 1295               0.24  техника для красоты и здоровья
# 1296               0.21               домашний текстиль
# 1297               0.20               домашний текстиль
# 1298               0.12  техника для красоты и здоровья
# 1299               0.94  техника для красоты и здоровья
#
#       Средний_просмотр_категорий_за_визит  Неоплаченные_продукты_штук_квартал  \
# 0                                       6                                   2
# 1                                       4                                   4
# 2                                       5                                   2
# 3                                       5                                   0
# 4                                       3                                   2
# ...                                   ...                                 ...
# 1295                                    5                                   3
# 1296                                    6                                   2
# 1297                                    3                                   2
# 1298                                    3                                   3
# 1299                                    4                                   5
#
#       Ошибка_сервиса  Страниц_за_визит
# 0                  1                 5
# 1                  2                 5
# 2                  1                 5
# 3                  6                 4
# 4                  3                 2
# ...              ...               ...
# 1295               3                11
# 1296               3                 9
# 1297               5                 7
# 1298               5                 7
# 1299               3                12
#
# [1300 rows x 13 columns]

# %%
market_file.columns = market_file.columns.str.lower().str.replace(' ', '_')

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
#  11  ошибка_сервиса                       1300 non-null   int64
#  12  страниц_за_визит                     1300 non-null   int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 132.2+ KB

# %%
market_file['покупательская_активность'].value_counts()
# Out:
# покупательская_активность
# прежний уровень    802
# снизилась          498
# Name: count, dtype: int64

# %%
categorical_columns = market_file.select_dtypes(include=['object']).columns

# %%
for column in categorical_columns:
    print(f"Value counts for '{column}'")
    print(market_file[column].value_counts())
# Out:
# Value counts for 'покупательская_активность'
# покупательская_активность
# прежний уровень    802
# снизилась          498
# Name: count, dtype: int64
# Value counts for 'тип_сервиса'
# тип_сервиса
# стандарт     914
# премиум      376
# стандартт     10
# Name: count, dtype: int64
# Value counts for 'разрешить_сообщать'
# разрешить_сообщать
# да     962
# нет    338
# Name: count, dtype: int64
# Value counts for 'популярная_категория'
# популярная_категория
# товары для детей                        330
# домашний текстиль                       251
# косметика и аксесуары                   223
# техника для красоты и здоровья          184
# мелкая бытовая техника и электроника    174
# кухонная посуда                         138
# Name: count, dtype: int64

# %%
market_file['тип_сервиса'].replace('стандартт', 'стандарт', inplace=True)
# Out:
# /var/folders/gr/bmbkm95x0_b5mk4w9zv0jbpr0000gn/T/ipykernel_80890/1295589626.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   market_file['тип_сервиса'].replace('стандартт', 'стандарт', inplace=True)

# %%
market_file['тип_сервиса'].value_counts()
# Out:
# тип_сервиса
# стандарт    924
# премиум     376
# Name: count, dtype: int64

# %%
market_file.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Предобработка market_money

# %%
market_money = market_money.apply(lambda col: col.str.lower() if col.dtype == 'object' else col)

# %%
market_money
# Out:
#           id               Период  Выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
market_money.columns = market_money.columns.str.lower().str.replace(' ', '_')

# %%
market_money['период'].value_counts()
# Out:
# период
# препредыдущий_месяц    1300
# текущий_месяц          1300
# предыдущий_месяц       1300
# Name: count, dtype: int64

# %%
market_money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Предобработка market_time

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
market_time = market_time.apply(lambda col: col.str.lower() if col.dtype == 'object' else col)

# %%
market_time
# Out:
#           id            Период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдцщий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдцщий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдцщий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдцщий_месяц     15
#
# [2600 rows x 3 columns]

# %%
market_time.columns = market_time.columns.str.lower().str.replace(' ', '_')

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
market_time['период'].value_counts()
# Out:
# период
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: count, dtype: int64

# %%
market_time = market_time.rename(columns={'период': 'период_время'})

# %%
market_time.duplicated().sum()
# Out:
# 0

# %%
market_time_pivot = market_time.pivot(index='id', columns='период_время', values='минут').reset_index()

# %%
market_time_pivot
# Out:
# период_время      id  предыдцщий_месяц  текущий_месяц
# 0             215348                13             14
# 1             215349                12             10
# 2             215350                 8             13
# 3             215351                11             13
# 4             215352                 8             11
# ...              ...               ...            ...
# 1295          216643                14              7
# 1296          216644                12             11
# 1297          216645                12             18
# 1298          216646                18              7
# 1299          216647                15             10
#
# [1300 rows x 3 columns]

# %%
market_time_pivot = market_time_pivot.rename(columns={
    'предыдцщий_месяц': 'время_предыдущий_месяц',
    'текущий_месяц': 'время_текущий_месяц'
})

# %% [markdown]
# ### Предобработка money

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money
# Out:
#           id  Прибыль
# 0     215348     0.98
# 1     215349     4.16
# 2     215350     3.13
# 3     215351     4.87
# 4     215352     4.21
# ...      ...      ...
# 1295  216643     4.44
# 1296  216644     6.11
# 1297  216645     3.29
# 1298  216646     4.03
# 1299  216647     3.28
#
# [1300 rows x 2 columns]

# %%
money.columns = money.columns.str.lower()

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Исследовательский анализ данных

# %%
data = [market_file, market_money, market_time, money]

# %%
for i in data:
    display(i.describe())
# Out:
#                   id  маркет_актив_6_мес  маркет_актив_тек_мес  длительность  \
# count    1300.000000         1300.000000           1300.000000   1300.000000
# mean   215997.500000            4.253769              4.011538    601.898462
# std       375.421985            1.014814              0.696868    249.856289
# min    215348.000000            0.900000              3.000000    110.000000
# 25%    215672.750000            3.700000              4.000000    405.500000
# 50%    215997.500000            4.200000              4.000000    606.000000
# 75%    216322.250000            4.900000              4.000000    806.000000
# max    216647.000000            6.600000              5.000000   1079.000000
#
#        акционные_покупки  средний_просмотр_категорий_за_визит  \
# count        1300.000000                           1300.00000
# mean            0.319808                              3.27000
# std             0.249843                              1.35535
# min             0.000000                              1.00000
# 25%             0.170000                              2.00000
# 50%             0.240000                              3.00000
# 75%             0.300000                              4.00000
# max             0.990000                              6.00000
#
#        неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит
# count                         1300.000000     1300.000000       1300.000000
# mean                             2.840000        4.185385          8.176923
# std                              1.971451        1.955298          3.978126
# min                              0.000000        0.000000          1.000000
# 25%                              1.000000        3.000000          5.000000
# 50%                              3.000000        4.000000          8.000000
# 75%                              4.000000        6.000000         11.000000
# max                             10.000000        9.000000         20.000000
#                   id        выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000
#                   id        минут
# count    2600.000000  2600.000000
# mean   215997.500000    13.336154
# std       375.349754     4.080198
# min    215348.000000     4.000000
# 25%    215672.750000    10.000000
# 50%    215997.500000    13.000000
# 75%    216322.250000    16.000000
# max    216647.000000    23.000000
#                   id      прибыль
# count    1300.000000  1300.000000
# mean   215997.500000     3.996631
# std       375.421985     1.013722
# min    215348.000000     0.860000
# 25%    215672.750000     3.300000
# 50%    215997.500000     4.045000
# 75%    216322.250000     4.670000
# max    216647.000000     7.430000

# %%
dataframe_names = ['market_file', 'market_money', 'market_time', 'money']

# %%
    for df, name in zip(data, dataframe_names):
        print(f"Графики для датафрейма: {name}")
        for column in df.columns.drop('id'):
            plt.figure(figsize=(8, 4))
            if df[column].dtype in ['int64', 'float64']:
                plt.hist(df[column].dropna(), bins=20, color='skyblue', edgecolor='black')
                plt.title(f'Гистограмма для столбца: {column}')
                plt.xlabel(column)
                plt.ylabel('Частота')
            elif df[column].dtype in ['object', 'category']:
                value_counts = df[column].value_counts()
                value_counts.plot(kind='bar', color='lightgreen', edgecolor='black')
                plt.title(f'Столбчатая диаграмма для столбца: {column}')
                plt.xlabel(column)
                plt.ylabel('Количество')
            plt.tight_layout()
            plt.show()
# Out:
# Графики для датафрейма: market_file
# Графики для датафрейма: market_money
# Графики для датафрейма: market_time
# Графики для датафрейма: money

# %%
market_money_pivot = market_money.pivot(index='id', columns='период', values='выручка').reset_index()

# %%
market_money_pivot
# Out:
# период      id  предыдущий_месяц  препредыдущий_месяц  текущий_месяц
# 0       215348               0.0                  0.0         3293.1
# 1       215349            5216.0               4472.0         4971.6
# 2       215350            5457.5               4826.0         5058.4
# 3       215351            6158.0               4793.0         6610.4
# 4       215352            5807.5               4594.0         5872.5
# ...        ...               ...                  ...            ...
# 1295    216643            3664.0               4704.0         4741.7
# 1296    216644            4729.0               5299.0         5353.0
# 1297    216645            5160.0               5334.0         5139.2
# 1298    216646            4923.0               4725.0         5224.6
# 1299    216647            4720.0               5183.0         4448.3
#
# [1300 rows x 4 columns]

# %%
market_money_pivot = market_money_pivot.rename(columns={
    'предыдущий_месяц': 'выручка_предыдущий_месяц',
    'препредыдущий_месяц': 'выручка_препредыдущий_месяц',
    'текущий_месяц': 'выручка_текущий_месяц'
})

# %%
market_money_pivot = market_money_pivot.query('выручка_предыдущий_месяц > 0 & \
выручка_препредыдущий_месяц > 0 & выручка_текущий_месяц > 0')

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# В выручке много выбросов, нужно это учесть при выборе модели.

# %%
data = [market_file, market_money_pivot, market_time_pivot, money]

# %%
dataframe_names = ['market_file', 'market_money', 'market_time', 'money']

# %%
# Определяем общее количество числовых признаков во всех датафреймах
total_numeric_columns = sum(df.select_dtypes(include=['float64', 'int64']).shape[1] for df in data)

# Определяем количество строк и столбцов для subplots
n_cols = 2  # Количество столбцов в subplot
n_rows = (total_numeric_columns + n_cols - 1) // n_cols  # Количество строк

# Создаем subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 5))
fig.suptitle('Ящики с усами для всех количественных признаков', fontsize=16)

# Индекс для отслеживания текущего subplot
ax_index = 0

# Проходим по каждому датафрейму и его числовым столбцам
for df, df_name in zip(data, dataframe_names):
    numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns  # Числовые столбцы
    for column in numeric_columns:
        ax = axes[ax_index // n_cols, ax_index % n_cols] if n_rows > 1 else axes[ax_index % n_cols]  # Выбираем subplot
        sns.boxplot(x=df[column], orient='h', ax=ax)  # Строим ящик с усами
        ax.set_title(f'{df_name}: {column}')  # Заголовок с именем датафрейма и столбца
        ax.set_xlabel('Значения')
        ax.set_ylabel('')
        ax_index += 1  # Переходим к следующему subplot

# Убираем пустые subplots, если количество графиков не кратно n_cols
if total_numeric_columns < n_rows * n_cols:
    for j in range(total_numeric_columns, n_rows * n_cols):
        fig.delaxes(axes.flatten()[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# По ящику с усами виден выброс в выручке в текущем месяце.

# %%
# Формируем numeric_columns_list
numeric_columns_list = []
for df_name, df in zip(dataframe_names, data):
    numeric_columns = df.select_dtypes(include=['number']).columns 
    for column in numeric_columns:
        numeric_columns_list.append((df_name, column))

print(numeric_columns_list)
# Out:
# [('market_file', 'id'), ('market_file', 'маркет_актив_6_мес'), ('market_file', 'маркет_актив_тек_мес'), ('market_file', 'длительность'), ('market_file', 'акционные_покупки'), ('market_file', 'средний_просмотр_категорий_за_визит'), ('market_file', 'неоплаченные_продукты_штук_квартал'), ('market_file', 'ошибка_сервиса'), ('market_file', 'страниц_за_визит'), ('market_money', 'id'), ('market_money', 'выручка_предыдущий_месяц'), ('market_money', 'выручка_препредыдущий_месяц'), ('market_money', 'выручка_текущий_месяц'), ('market_time', 'id'), ('market_time', 'время_предыдущий_месяц'), ('market_time', 'время_текущий_месяц'), ('money', 'id'), ('money', 'прибыль')]

# %%
# Определяем количество строк и столбцов для subplots
n_cols = 2  # Количество столбцов в subplot
n_rows = (total_numeric_columns + n_cols - 1) // n_cols  # Количество строк

# Создаем subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 5))
fig.suptitle('Гистограммы для всех количественных признаков', fontsize=16)

# Если axes не является массивом (когда n_rows = 1), преобразуем его в массив
if n_rows == 1:
    axes = axes.reshape(1, -1)

# Проходим по каждому числовому столбцу и строим гистограмму
for idx, (df_name, column) in enumerate(numeric_columns_list):
    ax = axes[idx // n_cols, idx % n_cols]  # Выбираем subplot
    df = data[dataframe_names.index(df_name)]  # Находим соответствующий датафрейм
    sns.histplot(df[column], kde=True, bins=30, ax=ax)  # Строим гистограмму
    ax.set_title(f'{df_name}: {column}')  # Заголовок с именем датафрейма и столбца
    ax.set_xlabel(column)
    ax.set_ylabel('Частота')

# Убираем пустые subplots, если количество графиков не кратно n_cols
if len(numeric_columns_list) < n_rows * n_cols:
    for j in range(total_numeric_columns, n_rows * n_cols):
        fig.delaxes(axes.flatten()[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# По графикам можно заметить выброс в текущей выручке. Также стоит отметить, что из всех построенных гистограм только прибыль и выручка в предыдущем месяце имеют распределение, похожее на нормальное. Это нужно учесть при построении корреляционной матрицы. Также по столбчатым диаграммам можно заметить дисбаланс классов.

# %% [markdown]
# ## Объединение таблиц

# %%
merged_market = market_file.merge(market_money_pivot, on='id', how='inner') \
                         .merge(market_time_pivot, on='id', how='inner')
display(merged_market.head())
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 снизилась     премиум                 да
# 1  215350                 снизилась    стандарт                нет
# 2  215351                 снизилась    стандарт                 да
# 3  215352                 снизилась    стандарт                нет
# 4  215353                 снизилась    стандарт                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
#
#   популярная_категория  средний_просмотр_категорий_за_визит  \
# 0     товары для детей                                    4
# 1    домашний текстиль                                    5
# 2     товары для детей                                    5
# 3     товары для детей                                    3
# 4    домашний текстиль                                    4
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# 0                                   4               2                 5
# 1                                   2               1                 5
# 2                                   0               6                 4
# 3                                   2               3                 2
# 4                                   1               1                 4
#
#    выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 0                    5216.0                       4472.0
# 1                    5457.5                       4826.0
# 2                    6158.0                       4793.0
# 3                    5807.5                       4594.0
# 4                    4738.5                       5124.0
#
#    выручка_текущий_месяц  время_предыдущий_месяц  время_текущий_месяц
# 0                 4971.6                      12                   10
# 1                 5058.4                       8                   13
# 2                 6610.4                      11                   13
# 3                 5872.5                       8                   11
# 4                 5388.5                      10                   10

# %%
merged_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1297 entries, 0 to 1296
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1297 non-null   int64
#  1   покупательская_активность            1297 non-null   object
#  2   тип_сервиса                          1297 non-null   object
#  3   разрешить_сообщать                   1297 non-null   object
#  4   маркет_актив_6_мес                   1297 non-null   float64
#  5   маркет_актив_тек_мес                 1297 non-null   int64
#  6   длительность                         1297 non-null   int64
#  7   акционные_покупки                    1297 non-null   float64
#  8   популярная_категория                 1297 non-null   object
#  9   средний_просмотр_категорий_за_визит  1297 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1297 non-null   int64
#  11  ошибка_сервиса                       1297 non-null   int64
#  12  страниц_за_визит                     1297 non-null   int64
#  13  выручка_предыдущий_месяц             1297 non-null   float64
#  14  выручка_препредыдущий_месяц          1297 non-null   float64
#  15  выручка_текущий_месяц                1297 non-null   float64
#  16  время_предыдущий_месяц               1297 non-null   int64
#  17  время_текущий_месяц                  1297 non-null   int64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 182.5+ KB

# %%
merged_market.query('выручка_текущий_месяц > 100000')
# Out:
#         id покупательская_активность тип_сервиса разрешить_сообщать  \
# 29  215380                 снизилась     премиум                нет
#
#     маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 29                 1.7                     4           637               0.94
#
#               популярная_категория  средний_просмотр_категорий_за_визит  \
# 29  техника для красоты и здоровья                                    3
#
#     неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# 29                                   2               4                 7
#
#     выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 29                    6077.0                       5051.0
#
#     выручка_текущий_месяц  время_предыдущий_месяц  время_текущий_месяц
# 29               106862.2                      12                   14

# %%
merged_market = merged_market.query('выручка_текущий_месяц < 100000')

# %% [markdown]
# ## Корреляционный анализ

# %%
corr_matrix = merged_market.drop('id', axis=1).phik_matrix(interval_cols=\
    ['маркет_актив_6_мес','маркет_актив_тек_мес ','длительность',\
     'акционные_покупки','средний_просмотр_категорий_за_визит%',\
     'неоплаченные_продукты_штук_квартал%','ошибка_сервиса','страниц_за_визит',\
    'выручка_предыдущий_месяц','выручка_препредыдущий_месяц','выручка_текущий_месяц',\
    'время_предыдущий_месяц','время_текущий_месяц'])

# %%
corr_matrix
# Out:
#                                      покупательская_активность  тип_сервиса  \
# покупательская_активность                             1.000000     0.129940
# тип_сервиса                                           0.129940     1.000000
# разрешить_сообщать                                    0.000000     0.289965
# маркет_актив_6_мес                                    0.544831     0.089911
# маркет_актив_тек_мес                                  0.000000     0.045258
# длительность                                          0.099901     0.401411
# акционные_покупки                                     0.506276     0.030010
# популярная_категория                                  0.299717     0.070809
# средний_просмотр_категорий_за_визит                   0.539607     0.185391
# неоплаченные_продукты_штук_квартал                    0.405041     0.113015
# ошибка_сервиса                                        0.224154     0.079515
# страниц_за_визит                                      0.749888     0.102594
# выручка_предыдущий_месяц                              0.224638     0.000000
# выручка_препредыдущий_месяц                           0.497393     0.069704
# выручка_текущий_месяц                                 0.197213     0.124216
# время_предыдущий_месяц                                0.685138     0.131814
# время_текущий_месяц                                   0.576770     0.000000
#
#                                      разрешить_сообщать  маркет_актив_6_мес  \
# покупательская_активность                      0.000000            0.544831
# тип_сервиса                                    0.289965            0.089911
# разрешить_сообщать                             1.000000            0.000000
# маркет_актив_6_мес                             0.000000            1.000000
# маркет_актив_тек_мес                           0.052618            0.079854
# длительность                                   0.253831            0.000000
# акционные_покупки                              0.012198            0.279553
# популярная_категория                           0.073684            0.150386
# средний_просмотр_категорий_за_визит            0.070359            0.206788
# неоплаченные_продукты_штук_квартал             0.162524            0.217731
# ошибка_сервиса                                 0.021839            0.142401
# страниц_за_визит                               0.042134            0.396769
# выручка_предыдущий_месяц                       0.080842            0.155476
# выручка_препредыдущий_месяц                    0.000000            0.315331
# выручка_текущий_месяц                          0.060907            0.039795
# время_предыдущий_месяц                         0.038387            0.363950
# время_текущий_месяц                            0.000000            0.330601
#
#                                      маркет_актив_тек_мес  длительность  \
# покупательская_активность                        0.000000      0.099901
# тип_сервиса                                      0.045258      0.401411
# разрешить_сообщать                               0.052618      0.253831
# маркет_актив_6_мес                               0.079854      0.000000
# маркет_актив_тек_мес                             1.000000      0.174233
# длительность                                     0.174233      1.000000
# акционные_покупки                                0.000000      0.000000
# популярная_категория                             0.136243      0.000000
# средний_просмотр_категорий_за_визит              0.246633      0.186795
# неоплаченные_продукты_штук_квартал               0.142887      0.128222
# ошибка_сервиса                                   0.116946      0.175608
# страниц_за_визит                                 0.000000      0.122495
# выручка_предыдущий_месяц                         0.051824      0.125572
# выручка_препредыдущий_месяц                      0.000000      0.113200
# выручка_текущий_месяц                            0.000000      0.147048
# время_предыдущий_месяц                           0.107945      0.026448
# время_текущий_месяц                              0.061410      0.101481
#
#                                      акционные_покупки  популярная_категория  \
# покупательская_активность                     0.506276              0.299717
# тип_сервиса                                   0.030010              0.070809
# разрешить_сообщать                            0.012198              0.073684
# маркет_актив_6_мес                            0.279553              0.150386
# маркет_актив_тек_мес                          0.000000              0.136243
# длительность                                  0.000000              0.000000
# акционные_покупки                             1.000000              0.122385
# популярная_категория                          0.122385              1.000000
# средний_просмотр_категорий_за_визит           0.199180              0.226116
# неоплаченные_продукты_штук_квартал            0.246665              0.254746
# ошибка_сервиса                                0.000000              0.000000
# страниц_за_визит                              0.311418              0.160300
# выручка_предыдущий_месяц                      0.060733              0.252097
# выручка_препредыдущий_месяц                   0.226381              0.043528
# выручка_текущий_месяц                         0.071094              0.237240
# время_предыдущий_месяц                        0.262324              0.195233
# время_текущий_месяц                           0.250558              0.089883
#
#                                      средний_просмотр_категорий_за_визит  \
# покупательская_активность                                       0.539607
# тип_сервиса                                                     0.185391
# разрешить_сообщать                                              0.070359
# маркет_актив_6_мес                                              0.206788
# маркет_актив_тек_мес                                            0.246633
# длительность                                                    0.186795
# акционные_покупки                                               0.199180
# популярная_категория                                            0.226116
# средний_просмотр_категорий_за_визит                             1.000000
# неоплаченные_продукты_штук_квартал                              0.334927
# ошибка_сервиса                                                  0.070315
# страниц_за_визит                                                0.262271
# выручка_предыдущий_месяц                                        0.098440
# выручка_препредыдущий_месяц                                     0.176828
# выручка_текущий_месяц                                           0.092597
# время_предыдущий_месяц                                          0.159837
# время_текущий_месяц                                             0.182568
#
#                                      неоплаченные_продукты_штук_квартал  \
# покупательская_активность                                      0.405041
# тип_сервиса                                                    0.113015
# разрешить_сообщать                                             0.162524
# маркет_актив_6_мес                                             0.217731
# маркет_актив_тек_мес                                           0.142887
# длительность                                                   0.128222
# акционные_покупки                                              0.246665
# популярная_категория                                           0.254746
# средний_просмотр_категорий_за_визит                            0.334927
# неоплаченные_продукты_штук_квартал                             1.000000
# ошибка_сервиса                                                 0.000000
# страниц_за_визит                                               0.268263
# выручка_предыдущий_месяц                                       0.193536
# выручка_препредыдущий_месяц                                    0.189320
# выручка_текущий_месяц                                          0.166017
# время_предыдущий_месяц                                         0.197933
# время_текущий_месяц                                            0.168998
#
#                                      ошибка_сервиса  страниц_за_визит  \
# покупательская_активность                  0.224154          0.749888
# тип_сервиса                                0.079515          0.102594
# разрешить_сообщать                         0.021839          0.042134
# маркет_актив_6_мес                         0.142401          0.396769
# маркет_актив_тек_мес                       0.116946          0.000000
# длительность                               0.175608          0.122495
# акционные_покупки                          0.000000          0.311418
# популярная_категория                       0.000000          0.160300
# средний_просмотр_категорий_за_визит        0.070315          0.262271
# неоплаченные_продукты_штук_квартал         0.000000          0.268263
# ошибка_сервиса                             1.000000          0.183682
# страниц_за_визит                           0.183682          1.000000
# выручка_предыдущий_месяц                   0.000000          0.148410
# выручка_препредыдущий_месяц                0.138558          0.339954
# выручка_текущий_месяц                      0.000000          0.139891
# время_предыдущий_месяц                     0.243978          0.478889
# время_текущий_месяц                        0.177180          0.382377
#
#                                      выручка_предыдущий_месяц  \
# покупательская_активность                            0.224638
# тип_сервиса                                          0.000000
# разрешить_сообщать                                   0.080842
# маркет_актив_6_мес                                   0.155476
# маркет_актив_тек_мес                                 0.051824
# длительность                                         0.125572
# акционные_покупки                                    0.060733
# популярная_категория                                 0.252097
# средний_просмотр_категорий_за_визит                  0.098440
# неоплаченные_продукты_штук_квартал                   0.193536
# ошибка_сервиса                                       0.000000
# страниц_за_визит                                     0.148410
# выручка_предыдущий_месяц                             1.000000
# выручка_препредыдущий_месяц                          0.358313
# выручка_текущий_месяц                                0.836281
# время_предыдущий_месяц                               0.126368
# время_текущий_месяц                                  0.196789
#
#                                      выручка_препредыдущий_месяц  \
# покупательская_активность                               0.497393
# тип_сервиса                                             0.069704
# разрешить_сообщать                                      0.000000
# маркет_актив_6_мес                                      0.315331
# маркет_актив_тек_мес                                    0.000000
# длительность                                            0.113200
# акционные_покупки                                       0.226381
# популярная_категория                                    0.043528
# средний_просмотр_категорий_за_визит                     0.176828
# неоплаченные_продукты_штук_квартал                      0.189320
# ошибка_сервиса                                          0.138558
# страниц_за_визит                                        0.339954
# выручка_предыдущий_месяц                                0.358313
# выручка_препредыдущий_месяц                             1.000000
# выручка_текущий_месяц                                   0.410478
# время_предыдущий_месяц                                  0.421709
# время_текущий_месяц                                     0.342117
#
#                                      выручка_текущий_месяц  \
# покупательская_активность                         0.197213
# тип_сервиса                                       0.124216
# разрешить_сообщать                                0.060907
# маркет_актив_6_мес                                0.039795
# маркет_актив_тек_мес                              0.000000
# длительность                                      0.147048
# акционные_покупки                                 0.071094
# популярная_категория                              0.237240
# средний_просмотр_категорий_за_визит               0.092597
# неоплаченные_продукты_штук_квартал                0.166017
# ошибка_сервиса                                    0.000000
# страниц_за_визит                                  0.139891
# выручка_предыдущий_месяц                          0.836281
# выручка_препредыдущий_месяц                       0.410478
# выручка_текущий_месяц                             1.000000
# время_предыдущий_месяц                            0.229351
# время_текущий_месяц                               0.256596
#
#                                      время_предыдущий_месяц  \
# покупательская_активность                          0.685138
# тип_сервиса                                        0.131814
# разрешить_сообщать                                 0.038387
# маркет_актив_6_мес                                 0.363950
# маркет_актив_тек_мес                               0.107945
# длительность                                       0.026448
# акционные_покупки                                  0.262324
# популярная_категория                               0.195233
# средний_просмотр_категорий_за_визит                0.159837
# неоплаченные_продукты_штук_квартал                 0.197933
# ошибка_сервиса                                     0.243978
# страниц_за_визит                                   0.478889
# выручка_предыдущий_месяц                           0.126368
# выручка_препредыдущий_месяц                        0.421709
# выручка_текущий_месяц                              0.229351
# время_предыдущий_месяц                             1.000000
# время_текущий_месяц                                0.410990
#
#                                      время_текущий_месяц
# покупательская_активность                       0.576770
# тип_сервиса                                     0.000000
# разрешить_сообщать                              0.000000
# маркет_актив_6_мес                              0.330601
# маркет_актив_тек_мес                            0.061410
# длительность                                    0.101481
# акционные_покупки                               0.250558
# популярная_категория                            0.089883
# средний_просмотр_категорий_за_визит             0.182568
# неоплаченные_продукты_штук_квартал              0.168998
# ошибка_сервиса                                  0.177180
# страниц_за_визит                                0.382377
# выручка_предыдущий_месяц                        0.196789
# выручка_препредыдущий_месяц                     0.342117
# выручка_текущий_месяц                           0.256596
# время_предыдущий_месяц                          0.410990
# время_текущий_месяц                             1.000000

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1, cmap="Greens")
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# Мультиколлинеарности нет

# %% [markdown]
# ## Использование пайплайнов

# %%
X_train, X_test, y_train, y_test = train_test_split(
    merged_market.drop(['покупательская_активность', 'id'], axis=1),
    merged_market['покупательская_активность'],
    test_size = 0.25, 
    random_state = RANDOM_STATE,
    stratify = merged_market['покупательская_активность'])

# %%
X_train
# Out:
#      тип_сервиса разрешить_сообщать  маркет_актив_6_мес  маркет_актив_тек_мес  \
# 310     стандарт                 да                 3.5                     3
# 647      премиум                 да                 4.4                     4
# 790     стандарт                нет                 4.0                     4
# 1224     премиум                 да                 4.5                     4
# 651     стандарт                 да                 4.9                     4
# ...          ...                ...                 ...                   ...
# 215      премиум                 да                 2.4                     4
# 599     стандарт                 да                 3.9                     5
# 915      премиум                нет                 3.2                     3
# 688      премиум                 да                 4.2                     4
# 667     стандарт                нет                 3.3                     4
#
#       длительность  акционные_покупки                  популярная_категория  \
# 310           1012               0.40        техника для красоты и здоровья
# 647            959               0.13  мелкая бытовая техника и электроника
# 790            748               0.28                 косметика и аксесуары
# 1224           482               0.25                 косметика и аксесуары
# 651            435               0.23                 косметика и аксесуары
# ...            ...                ...                                   ...
# 215            785               0.24                      товары для детей
# 599            827               0.25  мелкая бытовая техника и электроника
# 915            337               0.17                       кухонная посуда
# 688            919               0.14                     домашний текстиль
# 667            304               0.15  мелкая бытовая техника и электроника
#
#       средний_просмотр_категорий_за_визит  неоплаченные_продукты_штук_квартал  \
# 310                                     4                                   5
# 647                                     6                                   1
# 790                                     4                                   0
# 1224                                    3                                   2
# 651                                     3                                   2
# ...                                   ...                                 ...
# 215                                     3                                   1
# 599                                     6                                   1
# 915                                     3                                   1
# 688                                     3                                   2
# 667                                     5                                   3
#
#       ошибка_сервиса  страниц_за_визит  выручка_предыдущий_месяц  \
# 310                3                 5                    3715.0
# 647                3                 6                    4342.0
# 790                4                 9                    5660.5
# 1224               2                 9                    5567.0
# 651                5                 7                    5796.5
# ...              ...               ...                       ...
# 215                3                 6                    3877.0
# 599                4                 8                    5124.5
# 915                3                 8                    5063.0
# 688                5                20                    4988.0
# 667                4                 5                    5005.5
#
#       выручка_препредыдущий_месяц  выручка_текущий_месяц  \
# 310                        4511.0                 4638.0
# 647                        4342.0                 4472.0
# 790                        4885.0                 6462.6
# 1224                       5483.0                 5769.8
# 651                        4727.0                 6853.4
# ...                           ...                    ...
# 215                        4702.0                 4191.6
# 599                        4415.0                 5869.4
# 915                        5591.0                 4735.4
# 688                        4451.0                 5583.4
# 667                        4440.0                 5625.6
#
#       время_предыдущий_месяц  время_текущий_месяц
# 310                       11                    9
# 647                       12                   21
# 790                       14                   10
# 1224                       8                   22
# 651                       18                   19
# ...                      ...                  ...
# 215                        8                   14
# 599                       11                   13
# 915                       18                   18
# 688                       16                   17
# 667                       18                   11
#
# [972 rows x 16 columns]

# %%
ohe_columns = [
    'популярная_категория'
]
ord_columns = [
    'тип_сервиса','разрешить_сообщать'
]
num_columns = [
    'маркет_актив_6_мес', 'маркет_актив_тек_мес','длительность', 
    'акционные_покупки','средний_просмотр_категорий_за_визит',
    'неоплаченные_продукты_штук_квартал','ошибка_сервиса', 'страниц_за_визит',
    'выручка_предыдущий_месяц', 'выручка_препредыдущий_месяц', 'выручка_текущий_месяц',
    'время_предыдущий_месяц','время_текущий_месяц'
]

# %%
# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='error'))
    ]
    )

# %%
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline([
    ('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
    ('ord', OrdinalEncoder(
        categories=[
            ['стандарт','премиум'],
            ['нет','да']
        ],
        handle_unknown='use_encoded_value',
        unknown_value=np.nan
    )),
    ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
])

# %%
# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [('ohe', ohe_pipe, ohe_columns),
     ('ord', ord_pipe, ord_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
])

# %%
param_grid = [
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2, 5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    
    # словарь для модели KNeighborsClassifier() 
    {
        'models': [KNeighborsClassifier()],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']   
    },

    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE, 
            solver='liblinear', 
            penalty='l1'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, probability = True)],
        'models__C': range(1, 6),
        'models__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
        'models__degree': [2, 3, 4, 5,6.7],  # Только для kernel='poly'
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    }
]

# %%
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring='roc_auc',
    random_state=RANDOM_STATE,
    n_jobs=-1
)

# %%
randomized_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('ohe',
#                                                                                Pipeline(steps=[('simpleImputer_ohe',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('ohe',
#                                                                                                 OneHotEncoder(drop='first'))]),
#                                                                                ['популярная_категория']),
#                                                                               ('ord',
#                                                                                Pipeline(steps=[('simpleImputer_before_ord',
#                                                                                                 SimpleImputer(strategy='most...
#                                                                        solver='liblinear')],
#                                          'models__C': range(1, 5),
#                                          'preprocessor__num': [StandardScaler(),
#                                                                MinMaxScaler(),
#                                                                'passthrough']},
#                                         {'models': [SVC(probability=True,
#                                                         random_state=1202)],
#                                          'models__C': range(1, 6),
#                                          'models__degree': [2, 3, 4, 5, 6.7],
#                                          'models__kernel': ['linear', 'rbf',
#                                                             'poly', 'sigmoid'],
#                                          'preprocessor__num': [StandardScaler(),
#                                                                MinMaxScaler()]}],
#                    random_state=1202, scoring='roc_auc')

# %%
# Извлекаем лучшую модель
best_model = randomized_search.best_estimator_

# %%
print('Лучшая модель и её параметры:\n\n', best_model)
print ('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first'))]),
#                                                   ['популярная_категория']),
#                                                  ('ord',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder...
#                                                    'маркет_актив_тек_мес',
#                                                    'длительность',
#                                                    'акционные_покупки',
#                                                    'средний_просмотр_категорий_за_визит',
#                                                    'неоплаченные_продукты_штук_квартал',
#                                                    'ошибка_сервиса',
#                                                    'страниц_за_визит',
#                                                    'выручка_предыдущий_месяц',
#                                                    'выручка_препредыдущий_месяц',
#                                                    'выручка_текущий_месяц',
#                                                    'время_предыдущий_месяц',
#                                                    'время_текущий_месяц'])])),
#                 ('models',
#                  SVC(C=2, degree=2, probability=True, random_state=1202))])
# Метрика лучшей модели на тренировочной выборке: 0.9150731516640608

# %%
y_pred_proba = best_model.predict_proba(X_test)[:, 1]

# Рассчитываем ROC AUC
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC AUC на тестовой выборке: {roc_auc:.4f}")
# Out:
# ROC AUC на тестовой выборке: 0.8891

# %% [markdown]
# Я думаю, что нам важнее recall, чтобы минимизировать потерю клиентов. Однако precision тоже важна. Мы использовали roc auc потому что данная метрика не учитывает порог классификации, что нам подходит, так как важны как precision так и recall. Также по roc auc обычно сравнивают модели, что мы и сейчас и делали.
# Рассчитав roc auc на тестовой выборке можно заметить, что метрика снизилась, возможно из-за переобучения.

# %% [markdown]
# ## Анализ важности признаков

# %% [raw]
#     explainer = shap.KernelExplainer(
#         randomized_search.best_estimator_.named_steps['models'].predict_proba,
#         randomized_search.best_estimator_[-2].transform(X_test),
#         feature_names = randomized_search.best_estimator_[-2].get_feature_names_out()
#     )
#
#     sample = shap.sample(randomized_search.best_estimator_[-2].transform(X_test), 100)
#
#
#     shap_values_sec = explainer(sample)
#
#     shap.plots.beeswarm(shap_values_sec[:, :, 1], max_display=20)

info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %% [markdown]
# Как я понял, нужно объединить предсказанные вероятности принадлежности к классу и данные о прибыли и найти клиентов, которые приносят много прибыли и у которых высокая вероятность снижения покупательской активности. Однако в датафрейме money 1300 клиентов, а мы предсказали вероятности только для тестовых данных. Также не совсем понятно, как сопоставить вероятности с id, так как выборки делились случайно.

# %%
df_total = merged_market.merge(money, on='id', how='left')

# %%
test_proba_df = pd.DataFrame({
    'index': X_test.index,
    'вероятность': y_pred_proba
})

# %%
test_proba_df
# Out:
#      index  вероятность
# 0      541     0.354154
# 1     1097     0.333316
# 2      382     0.957581
# 3      445     0.038779
# 4      543     0.127100
# ..     ...          ...
# 319    958     0.091414
# 320   1232     0.227130
# 321   1256     0.795447
# 322    698     0.044647
# 323    387     0.977866
#
# [324 rows x 2 columns]

# %%
train_proba_df = pd.DataFrame({
    'index': X_train.index,
    'вероятность': y_predict
})

# %%
train_proba_df
# Out:
#      index  вероятность
# 0      310     0.959758
# 1      647     0.066495
# 2      790     0.117221
# 3     1224     0.071544
# 4      651     0.030418
# ..     ...          ...
# 967    215     0.932263
# 968    599     0.065083
# 969    915     0.027549
# 970    688     0.059565
# 971    667     0.054174
#
# [972 rows x 2 columns]

# %%
combined_proba = test_proba_df.set_index('index')['вероятность'].combine_first(
    train_proba_df.set_index('index')['вероятность']
).reset_index(name='вероятность')

# %%
merged_market = merged_market.merge(combined_proba, left_index=True, right_on='index', how='left')

# %%
merged_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  11  ошибка_сервиса                       1296 non-null   int64
#  12  страниц_за_визит                     1296 non-null   int64
#  13  выручка_предыдущий_месяц             1296 non-null   float64
#  14  выручка_препредыдущий_месяц          1296 non-null   float64
#  15  выручка_текущий_месяц                1296 non-null   float64
#  16  время_предыдущий_месяц               1296 non-null   int64
#  17  время_текущий_месяц                  1296 non-null   int64
#  18  index                                1296 non-null   int64
#  19  вероятность                          1296 non-null   float64
# dtypes: float64(6), int64(10), object(4)
# memory usage: 202.6+ KB

# %%
merged_market.drop(columns=['index'], inplace=True, errors='ignore')

# %%
merged_market = merged_market.merge(money, how='left')

# %%
merged_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1296 non-null   int64
#  1   покупательская_активность            1296 non-null   object
#  2   тип_сервиса                          1296 non-null   object
#  3   разрешить_сообщать                   1296 non-null   object
#  4   маркет_актив_6_мес                   1296 non-null   float64
#  5   маркет_актив_тек_мес                 1296 non-null   int64
#  6   длительность                         1296 non-null   int64
#  7   акционные_покупки                    1296 non-null   float64
#  8   популярная_категория                 1296 non-null   object
#  9   средний_просмотр_категорий_за_визит  1296 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1296 non-null   int64
#  11  ошибка_сервиса                       1296 non-null   int64
#  12  страниц_за_визит                     1296 non-null   int64
#  13  выручка_предыдущий_месяц             1296 non-null   float64
#  14  выручка_препредыдущий_месяц          1296 non-null   float64
#  15  выручка_текущий_месяц                1296 non-null   float64
#  16  время_предыдущий_месяц               1296 non-null   int64
#  17  время_текущий_месяц                  1296 non-null   int64
#  18  вероятность                          1296 non-null   float64
#  19  прибыль                              1296 non-null   float64
# dtypes: float64(7), int64(9), object(4)
# memory usage: 202.6+ KB

# %%
merged_market.head(10)
# Out:
#        id покупательская_активность тип_сервиса разрешить_сообщать  \
# 0  215349                 снизилась     премиум                 да
# 1  215350                 снизилась    стандарт                нет
# 2  215351                 снизилась    стандарт                 да
# 3  215352                 снизилась    стандарт                нет
# 4  215353                 снизилась    стандарт                 да
# 5  215354                 снизилась    стандарт                 да
# 6  215355                 снизилась    стандарт                нет
# 7  215356                 снизилась    стандарт                 да
# 8  215358                 снизилась    стандарт                 да
# 9  215360                 снизилась     премиум                 да
#
#    маркет_актив_6_мес  маркет_актив_тек_мес  длительность  акционные_покупки  \
# 0                 4.4                     4           819               0.75
# 1                 4.9                     3           539               0.14
# 2                 3.2                     5           896               0.99
# 3                 5.1                     3          1064               0.94
# 4                 3.3                     4           762               0.26
# 5                 5.1                     3           431               0.23
# 6                 4.7                     4           284               0.17
# 7                 4.2                     4           192               0.14
# 8                 4.7                     4           450               0.13
# 9                 3.9                     3           623               0.35
#
#     популярная_категория  средний_просмотр_категорий_за_визит  \
# 0       товары для детей                                    4
# 1      домашний текстиль                                    5
# 2       товары для детей                                    5
# 3       товары для детей                                    3
# 4      домашний текстиль                                    4
# 5  косметика и аксесуары                                    2
# 6       товары для детей                                    5
# 7  косметика и аксесуары                                    2
# 8      домашний текстиль                                    4
# 9        кухонная посуда                                    3
#
#    неоплаченные_продукты_штук_квартал  ошибка_сервиса  страниц_за_визит  \
# 0                                   4               2                 5
# 1                                   2               1                 5
# 2                                   0               6                 4
# 3                                   2               3                 2
# 4                                   1               1                 4
# 5                                   3               7                 2
# 6                                   1               6                 4
# 7                                   2               1                 3
# 8                                   2               6                 4
# 9                                   1               4                 7
#
#    выручка_предыдущий_месяц  выручка_препредыдущий_месяц  \
# 0                    5216.0                       4472.0
# 1                    5457.5                       4826.0
# 2                    6158.0                       4793.0
# 3                    5807.5                       4594.0
# 4                    4738.5                       5124.0
# 5                    5685.0                       4503.0
# 6                    3263.0                       4749.0
# 7                    4146.5                       4433.0
# 8                    3488.0                       4727.0
# 9                    5304.5                       5555.0
#
#    выручка_текущий_месяц  время_предыдущий_месяц  время_текущий_месяц  \
# 0                 4971.6                      12                   10
# 1                 5058.4                       8                   13
# 2                 6610.4                      11                   13
# 3                 5872.5                       8                   11
# 4                 5388.5                      10                   10
# 5                 5869.6                      11                   12
# 6                 3772.6                      12                   10
# 7                 4566.4                       6                    7
# 8                 4209.5                      14                   10
# 9                 5834.9                       9                    6
#
#    вероятность  прибыль
# 0     0.976210     4.16
# 1     0.333515     3.13
# 2     0.932309     4.87
# 3     0.973413     4.21
# 4     0.774518     3.95
# 5     0.899702     3.62
# 6     0.723634     5.26
# 7     0.976866     4.93
# 8     0.419012     3.06
# 9     0.565434     4.55

# %%
threshold = 0.7
threshold_profit = merged_market['прибыль'].median()

# %%
merged_market['сегмент'] = np.where(
    (merged_market['прибыль'] > threshold_profit) & (merged_market['вероятность'] > threshold),
    'высокая_прибыль_высокая_вероятность_снижения',
    np.where(
        (merged_market['прибыль'] > threshold_profit) & (merged_market['вероятность'] <= threshold),
        'высокая_прибыль_низкая_вероятность_снижения',
        'другие'
    )
)

# %%
merged_market['сегмент'].value_counts()
# Out:
# сегмент
# другие                                          648
# высокая_прибыль_низкая_вероятность_снижения     451
# высокая_прибыль_высокая_вероятность_снижения    197
# Name: count, dtype: int64

# %%
seg_1 = merged_market.query('`сегмент` == "высокая_прибыль_высокая_вероятность_снижения"')

# %%
seg_2 = merged_market.query('`сегмент` == "высокая_прибыль_низкая_вероятность_снижения"')

# %%
seg_3 = merged_market.query('`сегмент` == "другие"')

# %%
segments = [seg_1, seg_2, seg_3]

# %%
seg_name = ['seg_1','seg_2','seg_3']

# %%
numeric_columns_list = []
for name, seg in zip(seg_name, segments):
    numeric_columns = seg.select_dtypes(include=['number']).columns
    for column in numeric_columns:
        numeric_columns_list.append((name, column))

# %%
# Группируем столбцы по их названиям
column_groups = defaultdict(list)
for df_name, column in numeric_columns_list:
    column_groups[column].append((df_name, column))

# Определяем количество строк и столбцов для subplots
n_cols = len(segments)
n_rows = len(column_groups)

# Создаем subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, n_rows * 5))
fig.suptitle('Гистограммы для всех количественных признаков', fontsize=16)

# Если axes не является массивом (когда n_rows = 1), преобразуем его в массив
if n_rows == 1:
    axes = axes.reshape(1, -1)

# Проходим по каждому уникальному столбцу и строим гистограммы для всех датафреймов
for row_idx, (column, df_columns) in enumerate(column_groups.items()):
    for col_idx, (df_name, _) in enumerate(df_columns):
        ax = axes[row_idx, col_idx]
        df = segments[seg_name.index(df_name)]
        sns.histplot(df[column], kde=True, bins=30, ax=ax)
        ax.set_title(f'{df_name}: {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Частота')

# Убираем пустые subplots, если количество графиков не кратно n_cols
for row_idx in range(n_rows):
    for col_idx in range(len(column_groups[list(column_groups.keys())[row_idx]]), n_cols):
        fig.delaxes(axes[row_idx, col_idx])

plt.tight_layout()
fig.subplots_adjust(top=0.97)
plt.show()

# %% [markdown]
# Просмотрев данные графики, можно предположить, что сегмент покупателей с высокой вероятностью снижения активности смотрят меньше категорий, посещают меньше страниц и проводят меньше времени на сайте. Видимо данные покупатели знают чего они хотят и ищут конкретный товар. Также стоит отметить, что данный тип покупателей покупает меньше товаров по акции. Однако необходимо учитывать, что покупателей с более высокой вероятностью снижения покупательской активности меньше, чем остальных, поэтому нужно сделать поправку на это.

# %%
cat_columns_list = []
for name, seg in zip(seg_name, segments):
    categorial_columns = seg.select_dtypes(include=['object']).columns
    for column in categorial_columns:
        cat_columns_list.append((name, column))

# %%
# Группируем столбцы по их названиям
column_groups = defaultdict(list)
for df_name, column in cat_columns_list:
    column_groups[column].append((df_name, column))

# Определяем количество строк и столбцов для subplots
n_cols = len(segments)
n_rows = len(column_groups) 

# Создаем subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(16, n_rows * 5))
fig.suptitle('Гистограммы для всех количественных признаков', fontsize=20)

# Если axes не является массивом (когда n_rows = 1), преобразуем его в массив
if n_rows == 1:
    axes = axes.reshape(1, -1)

# Проходим по каждому уникальному столбцу и строим гистограммы для всех датафреймов
for row_idx, (column, df_columns) in enumerate(column_groups.items()):
    for col_idx, (df_name, _) in enumerate(df_columns):
        ax = axes[row_idx, col_idx]
        df = segments[seg_name.index(df_name)]
        
        # Считаем количество наблюдений для каждой категории
        value_counts = df[column].value_counts()
        
        # Строим столбчатую диаграмму
        ax.pie(
            value_counts.values, 
            labels=value_counts.index,  
            autopct='%1.1f%%', 
            startangle=90,
           )
        ax.set_title(f'{df_name}: {column}')
        ax.set_xlabel(column)
        ax.set_ylabel('Количество')

# Убираем пустые subplots, если количество графиков не кратно n_cols
for row_idx in range(n_rows):
    for col_idx in range(len(column_groups[list(column_groups.keys())[row_idx]]), n_cols):
        fig.delaxes(axes[row_idx, col_idx])

plt.tight_layout()
plt.show()

# %% [markdown]
# Среди категории покупателей с более высокой вероятностью снижения покупательской активности доля с премиум сервисом больше чем среди покупателей с низкой вероятностью снижения покупательской активности. Возможно покупатели с премиум сервисом не ощущают достаточных преимуществ обладания таким сервисом. Возможно компании стоит улучшить существующую программу лояльности, внедрить более персонализированный подход к премиум покупателям.

# %% [markdown]
# Я решил сравнить покупателей, приносящих высокую прибыль с высокой и низкой вероятностью снижения покупательской активности. Так как данная группа покупателей приносят более высокую прибыль, то скорее всего у них много общих черт, что позволит более объективно оценивать возможные причины снижения покупательской активности. Так же компании  важно удерживать клиентов, приносящих большую прибыль, поэтому я сконцентрировался на них. Основываясь на полученной информации я предположил, что основная причина возможного снижения покупательской активности заключается в слабой CRM системе.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данном проекте я построил модель предсказания снижения покупательской активности для интернет-магазина «В один клик», выделил сегменты покупателей, рассмотрел возможные причины снижения активности у покупателей, приносящих высокую прибыль с высокой вероятностью снижения активности, а также предложил возможные методы решения проблемы.
# Я изучил предоставленные данные о покупателях и провел предобработку: привел данные к нужному регистру и типу, удалил скрытые дубликаты, переименовал показатели во избежание путаницы. Для поиска лучшей модели я построил пайплан, который подобрал лучшую модель с гиперпараметрами, используя метрику roc auc. Такой моделью оказалась SVC модель с полиномиальным ядром 5 степени. Получив вероятности снижения покупательской активности я разделил покупателей на 3 сегмента: с высокой прибылью и вероятностью снижения активности, с высокой прибылью и низкой вероятностью снижения активности и других. Я решил проанализировать возможные причины снижения активности покупателей и предложить подходящие решения данной проблемы. На мой взгляд, основной причиной снижения активности может стать недостаточно развитая система CRM. Компании стоит пересмотреть сущствующую программу лояльности для удержания покупателей, приносящих большую прибыль. Так, например, можно рассмотреть наиболее популярные категории покупок данных покупателей и расширить их ассортимент, предлагать персональные скидки, акции и подарки для покупателей.
